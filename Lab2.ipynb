# %% [markdown]
# <a href="https://colab.research.google.com/github/yashkapur0403/23FE10CSE00593_Yash_Kapur_ML_Lab/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/heart.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# ...

# %%
df.describe()

fig, axs = plt.subplots(len(df.columns), 1, figsize=(7, 18), dpi=95)
for i, col in enumerate(df.columns):
    axs[i].boxplot(df[col], vert=False)
    axs[i].set_ylabel(col)
plt.tight_layout()
plt.show()

# %%
X = df.drop(columns=['target'])
y = df['target']
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)
print(X_normalized[:5])
# Out:
# [[0.47916667 1.         0.         0.29245283 0.19634703 0.
#   0.5        0.74045802 0.         0.16129032 1.         0.5
#   1.        ]
#  [0.5        1.         0.         0.43396226 0.17579909 1.
#   0.         0.64122137 1.         0.5        0.         0.
#   1.        ]
#  [0.85416667 1.         0.         0.48113208 0.10958904 0.
#   0.5        0.41221374 1.         0.41935484 0.         0.
#   1.        ]
#  [0.66666667 1.         0.         0.50943396 0.17579909 0.
#   0.5        0.6870229  0.         0.         1.         0.25
#   1.        ]
#  [0.6875     0.         0.         0.41509434 0.38356164 1.
#   0.5        0.26717557 0.         0.30645161 0.5        0.75
#   0.66666667]]

# %%
scaler = MinMaxScaler()
X_normalized = scaler.fit_transform(X)
print(X_normalized[:5])
# Out:
# [[0.47916667 1.         0.         0.29245283 0.19634703 0.
#   0.5        0.74045802 0.         0.16129032 1.         0.5
#   1.        ]
#  [0.5        1.         0.         0.43396226 0.17579909 1.
#   0.         0.64122137 1.         0.5        0.         0.
#   1.        ]
#  [0.85416667 1.         0.         0.48113208 0.10958904 0.
#   0.5        0.41221374 1.         0.41935484 0.         0.
#   1.        ]
#  [0.66666667 1.         0.         0.50943396 0.17579909 0.
#   0.5        0.6870229  0.         0.         1.         0.25
#   1.        ]
#  [0.6875     0.         0.         0.41509434 0.38356164 1.
#   0.5        0.26717557 0.         0.30645161 0.5        0.75
#   0.66666667]]

# %%
plt.pie(df['target'].value_counts(), labels=[
        'No disease', 'No Disease'], autopct='%.f%%', shadow=True)
plt.title('Outcome Proportionality')
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')
plt.show()
